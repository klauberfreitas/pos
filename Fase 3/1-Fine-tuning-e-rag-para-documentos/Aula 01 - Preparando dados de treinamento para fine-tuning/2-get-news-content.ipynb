# %%
import requests
from bs4 import BeautifulSoup
import json

# %%
def get_news_content(links_file):
    # Carrega o arquivo com os links e retorna uma lista
    with open(links_file, 'r') as file:
        links = set(file.readlines())
    news_contents = []

    for link in links:
        link = link.strip()  # Limpa a URL, se necessário
        print(link)
        response = requests.get(link)
        if response.status_code == 200:
            soup = BeautifulSoup(response.text, 'html.parser')

            # Localiza o elemento que contém o conteúdo do artigo
            article_content = soup.find('div', class_='article__content')
            if article_content:
                paragraphs = article_content.find_all('p', class_='paragraph inline-placeholder')
                # Concatena o texto de todos os parágrafos encontrados
                content = ' '.join(p.get_text(strip=True) for p in paragraphs)
                news_contents.append(content)
                print(content)
            else:
                news_contents.append("Conteúdo não encontrado.")
        else:
            news_contents.append(f"Falha ao extrair o conteúdo da notícia: {response.status_code}")

    # Salva o conteúdo em um arquivo JSON
    with open('news_contents.json', 'w') as json_file:
        json.dump({"news_content": news_contents}, json_file)

# Chamada da função para extrair os conteúdos
get_news_content('CNN_Links.txt')
# Out:
# https://www.cnn.com/2025/01/22/middleeast/yemen-houthi-galaxy-leader-crew-free-intl-latam/index.html
#
# https://www.cnn.com/2025/01/25/africa/un-peacekeepers-drc-congo-m23-afr-intl-latam/index.html
#
# https://www.cnn.com/2025/01/01/style/new-buildings-architecture-2025/index.html
#
# https://www.cnn.com/2024/12/16/style/1-undershaft-tower-london-scli-intl-gbr/index.html
#
# https://www.cnn.com/2025/01/24/world/putin-trump-ukraine-crisis-talks-intl/index.html
#
# https://www.cnn.com/2025/01/21/weather/winter-storm-south-tuesday-hnk/index.html
#
# https://www.cnn.com/2025/01/22/americas/colombia-displaced-deadly-rebel-clashes-intl-latam/index.html
#
# https://www.cnn.com/2025/01/26/style/louvre-museum-couture-exhibition/index.html
#
# https://www.cnn.com/2025/01/26/sport/kylian-mbappe-real-madrid-hat-trick-spt-intl/index.html
#
# https://www.cnn.com/2025/01/24/travel/delta-air-lines-emergency-slide/index.html
#
# https://www.cnn.com/2025/01/22/asia/same-sex-couples-marriage-equality-thailand-intl-hnk/index.html
#
# https://www.cnn.com/2025/01/23/europe/storm-eowyn-uk-ireland-intl-latam/index.html
#
# https://www.cnn.com/2025/01/25/europe/elon-musk-germany-afd-protests-intl-latam/index.html
#
# https://www.cnn.com/2025/01/24/middleeast/gaza-checkpoint-us-contractor-israel-intl/index.html
#
# https://www.cnn.com/2025/01/26/asia/south-koreas-president-charged-insurrection-intl/index.html
#
# https://www.cnn.com/2025/01/26/europe/belarus-lukashenko-presidential-election-intl/index.html
#
# https://www.cnn.com/2025/01/24/middleeast/israel-lebanon-hezbollah-withdrawal-intl/index.html
#
# https://www.cnn.com/2025/01/26/africa/sudan-hospital-north-darfur-airstrike-70-killed-intl/index.html
